# %% [markdown]
# # Assignment-9: K-Means Clustering
#
# **Objective:** Apply K-Means clustering on a dataset, understand cluster formation, and visualize results.
#
# ---

# %% [markdown]
# ## Q1: Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# ### (Helper) Load Iris Dataset (features only — unlabeled)

# %%
iris = load_iris(as_frame=True)
df = iris.frame.copy()
df = df.drop(columns=['target'])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ## Q2: Dataset Overview

# %%
print('Shape:', df.shape)
print('\nColumns:', df.columns.tolist())
df.describe()
# Out:
# Shape: (150, 4)
#
# Columns: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ## Q3: Select Features for Clustering (Two Features for Visualization)

# %%
X = df[['sepal length (cm)', 'sepal width (cm)']]
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)
# 0                5.1               3.5
# 1                4.9               3.0
# 2                4.7               3.2
# 3                4.6               3.1
# 4                5.0               3.6

# %% [markdown]
# ## Q4: Visualize Raw Data (Scatter Plot)

# %%
plt.scatter(X.iloc[:,0], X.iloc[:,1])
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Raw Data Visualization')
plt.show()

# %% [markdown]
# ## Q5: Apply K-Means Algorithm (K = 3)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
print('Model trained')
# Out:
# Model trained

# %% [markdown]
# ## Q6: Assign Cluster Labels to Dataset

# %%
X_clustered = X.copy()
X_clustered['Cluster'] = kmeans.labels_
X_clustered.head()
# Out:
#    sepal length (cm)  sepal width (cm)  Cluster
# 0                5.1               3.5        2
# 1                4.9               3.0        2
# 2                4.7               3.2        2
# 3                4.6               3.1        2
# 4                5.0               3.6        2

# %% [markdown]
# ## Q7: Elbow Method to Find Best K

# %%
sse = []
K = range(1, 9)
for k in K:
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X)
    sse.append(km.inertia_)

plt.plot(K, sse, marker='o')
plt.xlabel('Number of clusters (K)')
plt.ylabel('SSE / Inertia')
plt.title('Elbow Method')
plt.show()

# %% [markdown]
# ## Q8: Visualize Final Clusters with Centroids

# %%
plt.scatter(X.iloc[:,0], X.iloc[:,1], c=kmeans.labels_)
centers = kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], marker='X', s=200)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('K-Means Clusters with Centroids')
plt.show()

# %% [markdown]
# ## Q9: Interpret Clustering Results

# %% [markdown]
# The graph shows the result of applying K-Means clustering (K = 3) on the dataset using Sepal Length (x-axis) and Sepal Width (y-axis).
#
# Key Observations:
# 1. Three Distinct Clusters:
# The data is divided into three groups, each represented by a different color (yellow, cyan, purple).
# This indicates that the algorithm successfully identified three natural groupings in the dataset.
# 2. Cluster Characteristics:
# Yellow cluster (left side):
# Lower sepal length (~4.5–5.5) and relatively higher sepal width → compact and clearly separated.
# 3. Cyan cluster (middle):
# Moderate sepal length (~5.5–6.2) and lower width → slightly scattered.
# 4. Purple cluster (right side):
# Higher sepal length (~6.2–8.0) and moderate width → more spread out.
# 5. Centroids (Blue “X” marks):
# Each cluster has a centroid representing the mean position of that cluster.
# Points are grouped based on minimum distance to these centroids.
# 6. Separation & Overlap:
# The left cluster is well-separated, showing strong distinction.
# The middle and right clusters slightly overlap, indicating some similarity between those data points.

# %% [markdown]
# ## Q10: Conclusion (Write in your own words)

# %% [markdown]
# The implementation and visualization demonstrate that the applied machine learning technique effectively analyzes the dataset and produces meaningful results. The graph clearly reflects the underlying pattern in the data, showing that the model is able to learn relationships (either grouping, classification, or prediction) accurately.
#
# The results indicate that:
#
# The model performs efficiently on the given dataset.
# The visual representation supports the correctness of the approach.
# The outcomes are consistent with expected behavior of the algorithm.
#
# Final takeaway:
# The experiment confirms that the chosen algorithm is suitable for the problem and can be reliably used for similar datasets to obtain accurate and interpretable results.Explain briefly:
# - how K-Means works,
# - usefulness of clustering,
# - what you observed in this experiment.

# %% [markdown]
# ---
# ### ✔ End of Assignment-9
